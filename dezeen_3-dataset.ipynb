# %% [markdown]
# # Introduction
# This part of the repository builds a detection system based on YOLOv4 object detector.

# %% [markdown]
# # Environment setup

# %% [markdown]
# ## Google Drive mount
# I'm using Google Colaboratory as my default platform, therefore I need to set up my environment to integrate it with Google Drive. You can skip this bit if you're working locally.
#
# 1. Mount Google Drive on the runtime to be able to read and write files. This will ask you to log in to your Google Account and provide an authorization code.
# 2. Create a symbolic link to a working directory
# 3. Change the directory to the one where I cloned my repository.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/My\ Drive/Colab\ Notebooks/dezeenAI /mydrive

# %%
# %cd /mydrive
# Out:
# /content/gdrive/My Drive/Colab Notebooks/dezeenAI

# %% [markdown]
# ## Libraries & functions
# - `sys` - system-specific parameters and functions
# - `os.path` - common pathname manipulations
# - `timeit` - cell runtime

# %%
import sys
import os.path
import timeit

# %% [markdown]
# # Open Images Dataset v6
# To add extra classes and improve performance let's download some more data from [Open Images Dataset v6](https://storage.googleapis.com/openimages/web/index.html). To do so let's use [OIDv4 ToolKit](https://github.com/theAIGuysCode/OIDv4_ToolKit).

# %% [markdown]
# ## Categories
# 1. Create a list of Open Images categories to download
# 2. Create a string of collapsed category names for later use as a command parameter
# 3. Export category list to a txt file

# %%
classes = [
           'Sink',
           'Stairs',
           'Chair',
           'Cabinetry',
           'Desk',
           'Studio couch',
           'Couch',
           'Door',
           'Shower',
           'Wardrobe',
           'Nightstand',
           'Bathtub',
           'Houseplant',
           'Sofa bed',
           'Curtain',
           'Bed',
           'Fireplace',
           'Bookcase',
           'Table',
           'Mirror',
           'Chest of drawers',
           'Cupboard',
           'Coffee table',
           'Toilet',
           'Bench',
           'Window',
           'Closet',
           'Lamp',
           'Drawer',
           'Stool'
           ]

# %%
classes_dashed = ' '.join([cls.replace(' ', '_') for cls in classes])
classes_dashed
# Out:
# 'Sink Stairs Chair Cabinetry Desk Studio_couch Couch Door Shower Wardrobe Nightstand Bathtub Houseplant Sofa_bed Curtain Bed Fireplace Bookcase Table Mirror Chest_of_drawers Cupboard Coffee_table Toilet Bench Window Closet Lamp Drawer Stool'

# %%
# %cd /mydrive/OIDv4_ToolKit/
with open('classes.txt', 'w') as output:
    output.write('\n'.join(classes))
# Out:
# /content/gdrive/My Drive/Colab Notebooks/dezeenAI/OIDv4_ToolKit

# %% [markdown]
# ## OIDv4_ToolKit
# Let's use the [OIDv4_ToolKit](https://github.com/theAIGuysCode/OIDv4_ToolKit) repository to download the image files from the Open Image Dataset

# %%
# %cd /mydrive
# !git clone https://github.com/theAIGuysCode/OIDv4_ToolKit.git

# %% [markdown]
# ## Install the library requirements
# Let's install the library requirements essential for the toolkit to work properly.

# %%
# !pip install -r /mydrive/OIDv4_ToolKit/requirements.txt
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from -r /mydrive/OIDv4_ToolKit/requirements.txt (line 1)) (1.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from -r /mydrive/OIDv4_ToolKit/requirements.txt (line 2)) (1.18.5)
# Collecting awscli
#   Downloading https://files.pythonhosted.org/packages/94/4f/2d9dd0503f63698326b3c0699f95f10d0a9f9560801053266aeb5b85d895/awscli-1.18.187-py2.py3-none-any.whl (3.4MB)
#      |████████████████████████████████| 3.5MB 5.7MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from -r /mydrive/OIDv4_ToolKit/requirements.txt (line 4)) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from -r /mydrive/OIDv4_ToolKit/requirements.txt (line 5)) (4.41.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from -r /mydrive/OIDv4_ToolKit/requirements.txt (line 6)) (4.1.2.30)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->-r /mydrive/OIDv4_ToolKit/requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->-r /mydrive/OIDv4_ToolKit/requirements.txt (line 1)) (2018.9)
# Collecting docutils<0.16,>=0.10
#   Downloading https://files.pythonhosted.org/packages/22/cd/a6aa959dca619918ccb55023b4cb151949c64d4d5d55b3f4ffd7eee0c6e8/docutils-0.15.2-py3-none-any.whl (547kB)
#      |████████████████████████████████| 552kB 47.3MB/s
# Collecting rsa<=4.5.0,>=3.1.2; python_version != "3.4"
#   Downloading https://files.pythonhosted.org/packages/26/f8/8127fdda0294f044121d20aac7785feb810e159098447967a6103dedfb96/rsa-4.5-py2.py3-none-any.whl
# Collecting colorama<0.4.4,>=0.2.5; python_version != "3.4"
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Collecting botocore==1.19.27
#   Downloading https://files.pythonhosted.org/packages/e4/e6/f41a1936b7602d9badb66ae9677e5d4cfc8bd9955a9a1618a0945f2f5b1b/botocore-1.19.27-py2.py3-none-any.whl (7.0MB)
#      |████████████████████████████████| 7.0MB 40.3MB/s
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/69/79/e6afb3d8b0b4e96cefbdc690f741d7dd24547ff1f94240c997a26fa908d3/s3transfer-0.3.3-py2.py3-none-any.whl (69kB)
#      |████████████████████████████████| 71kB 7.7MB/s
# Requirement already satisfied: PyYAML<5.4,>=3.10; python_version != "3.4" in /usr/local/lib/python3.6/dist-packages (from awscli->-r /mydrive/OIDv4_ToolKit/requirements.txt (line 3)) (3.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->-r /mydrive/OIDv4_ToolKit/requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<=4.5.0,>=3.1.2; python_version != "3.4"->awscli->-r /mydrive/OIDv4_ToolKit/requirements.txt (line 3)) (0.4.8)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: botocore 1.19.27 has requirement urllib3<1.27,>=1.25.4; python_version != "3.4", but you'll have urllib3 1.24.3 which is incompatible.
# Installing collected packages: docutils, rsa, colorama, jmespath, botocore, s3transfer, awscli
#   Found existing installation: docutils 0.16
#     Uninstalling docutils-0.16:
#       Successfully uninstalled docutils-0.16
#   Found existing installation: rsa 4.6
#     Uninstalling rsa-4.6:
#       Successfully uninstalled rsa-4.6
# Successfully installed awscli-1.18.187 botocore-1.19.27 colorama-0.4.3 docutils-0.15.2 jmespath-0.10.0 rsa-4.5 s3transfer-0.3.3

# %% [markdown]
# ## Download training & validation sets
# Let's use OIDv4_ToolKit's `main.py downloader` script to download the image files train and validation sets in the 5:1 ratio.
# - `--classes` followed by previously created collapsed string of category names points to the image classes we want to download
# - `--type_csv` followed by `train` on `validation` indicates which dataset type we want to download
# - `--limit` followed by an integer indicates the maximum of files we want to download
# - `--multiclasses` followed by `1` or `0` indicates if we're deadling with a single- or a multiclass classification problem

# %% [markdown]
# ### Train set

# %%
start = timeit.default_timer() # start the times

# !python3 main.py downloader --classes {classes_dashed} --type_csv train --limit 500 --multiclasses 1

stop = timeit.default_timer() # stop the timer
print('Runtime: {} seconds.'.format(stop-start))
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Sink', 'Stairs', 'Chair', 'Cabinetry', 'Desk', 'Studio couch', 'Couch', 'Door', 'Shower', 'Wardrobe', 'Nightstand', 'Bathtub', 'Houseplant', 'Sofa bed', 'Curtain', 'Bed', 'Fireplace', 'Bookcase', 'Table', 'Mirror', 'Chest of drawers', 'Cupboard', 'Coffee table', 'Toilet', 'Bench', 'Window', 'Closet', 'Lamp', 'Drawer', 'Stool'] together.
#    [ERROR] | Missing the train-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...100%, 1138 MB, 32424 KB/s, 35 seconds passed
# [DOWNLOAD] | File train-annotations-bbox.csv downloaded into OID/csv_folder/train-annotations-bbox.csv.
#
# Sink
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 1442 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 500 images in train.
# 100% 500/500 [03:59<00:00,  2.09it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Sink of train.
#     [INFO] | Labels creation completed.
#
# Stairs
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 4533 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 500 images in train.
# 100% 500/500 [03:42<00:00,  2.24it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Stairs of train.
#     [INFO] | Labels creation completed.
#
# Chair
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 25504 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 497 images in train.
# 100% 497/497 [03:39<00:00,  2.26it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Chair of train.
#     [INFO] | Labels creation completed.
#
# Cabinetry
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 3001 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 420 images in train.
# 100% 420/420 [03:05<00:00,  2.27it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Cabinetry of train.
#     [INFO] | Labels creation completed.
#
# Desk
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 9472 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 448 images in train.
# 100% 448/448 [03:18<00:00,  2.26it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Desk of train.
#     [INFO] | Labels creation completed.
#
# Studio couch
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 1133 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 487 images in train.
# 100% 487/487 [03:39<00:00,  2.22it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Studio couch of train.
#     [INFO] | Labels creation completed.
#
# Couch
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 3321 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 456 images in train.
# 100% 456/456 [03:24<00:00,  2.23it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Couch of train.
#     [INFO] | Labels creation completed.
#
# Door
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 13382 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 478 images in train.
# 100% 478/478 [03:35<00:00,  2.22it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Door of train.
#     [INFO] | Labels creation completed.
#
# Shower
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 206 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 195 images in train.
# 100% 195/195 [01:27<00:00,  2.22it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Shower of train.
#     [INFO] | Labels creation completed.
#
# Wardrobe
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 208 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 206 images in train.
# 100% 206/206 [01:36<00:00,  2.13it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Wardrobe of train.
#     [INFO] | Labels creation completed.
#
# Nightstand
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 773 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 467 images in train.
# 100% 467/467 [03:40<00:00,  2.12it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Nightstand of train.
#     [INFO] | Labels creation completed.
#
# Bathtub
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 533 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 427 images in train.
# 100% 427/427 [03:18<00:00,  2.15it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Bathtub of train.
#     [INFO] | Labels creation completed.
#
# Houseplant
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 8932 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 466 images in train.
# 100% 466/466 [03:39<00:00,  2.13it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Houseplant of train.
#     [INFO] | Labels creation completed.
#
# Sofa bed
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 1132 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 249 images in train.
# 100% 249/249 [01:54<00:00,  2.17it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Sofa bed of train.
#     [INFO] | Labels creation completed.
#
# Curtain
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 2616 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 430 images in train.
# 100% 430/430 [03:23<00:00,  2.11it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Curtain of train.
#     [INFO] | Labels creation completed.
#
# Bed
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 2933 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 345 images in train.
# 100% 345/345 [02:37<00:00,  2.19it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Bed of train.
#     [INFO] | Labels creation completed.
#
# Fireplace
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 685 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 472 images in train.
# 100% 472/472 [03:40<00:00,  2.14it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Fireplace of train.
#     [INFO] | Labels creation completed.
#
# Bookcase
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 3388 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 462 images in train.
# 100% 462/462 [03:32<00:00,  2.17it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Bookcase of train.
#     [INFO] | Labels creation completed.
#
# Table
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 44845 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 323 images in train.
# 100% 323/323 [02:32<00:00,  2.12it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Table of train.
#     [INFO] | Labels creation completed.
#
# Mirror
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 1146 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 460 images in train.
# 100% 460/460 [03:29<00:00,  2.19it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Mirror of train.
#     [INFO] | Labels creation completed.
#
# Chest of drawers
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 1151 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 315 images in train.
# 100% 315/315 [02:26<00:00,  2.15it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Chest of drawers of train.
#     [INFO] | Labels creation completed.
#
# Cupboard
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 872 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 297 images in train.
# 100% 297/297 [02:20<00:00,  2.12it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Cupboard of train.
#     [INFO] | Labels creation completed.
#
# Coffee table
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 2840 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 378 images in train.
# 100% 378/378 [02:57<00:00,  2.12it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Coffee table of train.
#     [INFO] | Labels creation completed.
#
# Toilet
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 862 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 417 images in train.
# 100% 417/417 [03:12<00:00,  2.17it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Toilet of train.
#     [INFO] | Labels creation completed.
#
# Bench
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 3630 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 480 images in train.
# 100% 480/480 [03:44<00:00,  2.14it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Bench of train.
#     [INFO] | Labels creation completed.
#
# Window
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 59833 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 435 images in train.
# 100% 435/435 [03:20<00:00,  2.17it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Window of train.
#     [INFO] | Labels creation completed.
#
# Closet
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 381 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 277 images in train.
# 100% 277/277 [02:15<00:00,  2.05it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Closet of train.
#     [INFO] | Labels creation completed.
#
# Lamp
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 1565 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 466 images in train.
# 100% 466/466 [03:43<00:00,  2.09it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Lamp of train.
#     [INFO] | Labels creation completed.
#
# Drawer
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 1623 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 175 images in train.
# 100% 175/175 [01:25<00:00,  2.04it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Drawer of train.
#     [INFO] | Labels creation completed.
#
# Stool
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 576 online images for train.
#     [INFO] | Limiting to 500 images.
#     [INFO] | Download of 467 images in train.
# 100% 467/467 [03:48<00:00,  2.04it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Stool of train.
#     [INFO] | Labels creation completed.

# %% [markdown]
# ### Validation set

# %%
start = timeit.default_timer() # start the times

# !python3 main.py downloader --classes {classes_dashed} --type_csv validation --limit 100 --multiclasses 1

stop = timeit.default_timer() # stop the timer
print('Runtime: {} seconds.'.format(stop-start))
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Sink', 'Stairs', 'Chair', 'Cabinetry', 'Desk', 'Studio couch', 'Couch', 'Door', 'Shower', 'Wardrobe', 'Nightstand', 'Bathtub', 'Houseplant', 'Sofa bed', 'Curtain', 'Bed', 'Fireplace', 'Bookcase', 'Table', 'Mirror', 'Chest of drawers', 'Cupboard', 'Coffee table', 'Toilet', 'Bench', 'Window', 'Closet', 'Lamp', 'Drawer', 'Stool'] together.
#
# Sink
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 46 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 46 images in validation.
# 100% 46/46 [00:41<00:00,  1.10it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Sink of validation.
#     [INFO] | Labels creation completed.
#
# Stairs
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 30 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 30 images in validation.
# 100% 30/30 [00:28<00:00,  1.05it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Stairs of validation.
#     [INFO] | Labels creation completed.
#
# Chair
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 253 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 100 images in validation.
# 100% 100/100 [01:15<00:00,  1.32it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Chair of validation.
#     [INFO] | Labels creation completed.
#
# Cabinetry
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 130 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 79 images in validation.
# 100% 79/79 [01:02<00:00,  1.27it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Cabinetry of validation.
#     [INFO] | Labels creation completed.
#
# Desk
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 35 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 25 images in validation.
# 100% 25/25 [00:26<00:00,  1.06s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Desk of validation.
#     [INFO] | Labels creation completed.
#
# Studio couch
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 42 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 36 images in validation.
# 100% 36/36 [00:31<00:00,  1.16it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Studio couch of validation.
#     [INFO] | Labels creation completed.
#
# Couch
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 34 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 18 images in validation.
# 100% 18/18 [00:15<00:00,  1.13it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Couch of validation.
#     [INFO] | Labels creation completed.
#
# Door
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 122 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 92 images in validation.
# 100% 92/92 [01:13<00:00,  1.26it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Door of validation.
#     [INFO] | Labels creation completed.
#
# Shower
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 8 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 8 images in validation.
# 100% 8/8 [00:10<00:00,  1.35s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Shower of validation.
#     [INFO] | Labels creation completed.
#
# Wardrobe
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 6 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 3 images in validation.
# 100% 3/3 [00:08<00:00,  2.74s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Wardrobe of validation.
#     [INFO] | Labels creation completed.
#
# Nightstand
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 21 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 16 images in validation.
# 100% 16/16 [00:15<00:00,  1.06it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Nightstand of validation.
#     [INFO] | Labels creation completed.
#
# Bathtub
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 14 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 14 images in validation.
# 100% 14/14 [00:13<00:00,  1.01it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Bathtub of validation.
#     [INFO] | Labels creation completed.
#
# Houseplant
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 214 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 94 images in validation.
# 100% 94/94 [01:13<00:00,  1.28it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Houseplant of validation.
#     [INFO] | Labels creation completed.
#
# Sofa bed
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 42 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 6 images in validation.
# 100% 6/6 [00:10<00:00,  1.68s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Sofa bed of validation.
#     [INFO] | Labels creation completed.
#
# Curtain
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 38 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 33 images in validation.
# 100% 33/33 [00:30<00:00,  1.07it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Curtain of validation.
#     [INFO] | Labels creation completed.
#
# Bed
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 92 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 67 images in validation.
# 100% 67/67 [00:57<00:00,  1.16it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Bed of validation.
#     [INFO] | Labels creation completed.
#
# Fireplace
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 35 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 32 images in validation.
# 100% 32/32 [00:29<00:00,  1.10it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Fireplace of validation.
#     [INFO] | Labels creation completed.
#
# Bookcase
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 67 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 59 images in validation.
# 100% 59/59 [00:49<00:00,  1.20it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Bookcase of validation.
#     [INFO] | Labels creation completed.
#
# Table
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 431 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 76 images in validation.
# 100% 76/76 [01:00<00:00,  1.27it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Table of validation.
#     [INFO] | Labels creation completed.
#
# Mirror
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 20 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 19 images in validation.
# 100% 19/19 [00:16<00:00,  1.16it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Mirror of validation.
#     [INFO] | Labels creation completed.
#
# Chest of drawers
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 62 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 22 images in validation.
# 100% 22/22 [00:24<00:00,  1.09s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Chest of drawers of validation.
#     [INFO] | Labels creation completed.
#
# Cupboard
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 61 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 3 images in validation.
# 100% 3/3 [00:08<00:00,  2.80s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Cupboard of validation.
#     [INFO] | Labels creation completed.
#
# Coffee table
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 31 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 11 images in validation.
# 100% 11/11 [00:12<00:00,  1.12s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Coffee table of validation.
#     [INFO] | Labels creation completed.
#
# Toilet
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 25 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 19 images in validation.
# 100% 19/19 [00:16<00:00,  1.15it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Toilet of validation.
#     [INFO] | Labels creation completed.
#
# Bench
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 0 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | All images already downloaded.
#     [INFO] | Creating labels for Bench of validation.
#     [INFO] | Labels creation completed.
#
# Window
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 450 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 81 images in validation.
# 100% 81/81 [01:02<00:00,  1.29it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Window of validation.
#     [INFO] | Labels creation completed.
#
# Closet
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 10 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 5 images in validation.
# 100% 5/5 [00:09<00:00,  1.89s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Closet of validation.
#     [INFO] | Labels creation completed.
#
# Lamp
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 33 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 33 images in validation.
# 100% 33/33 [00:29<00:00,  1.11it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Lamp of validation.
#     [INFO] | Labels creation completed.
#
# Drawer
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 77 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 3 images in validation.
# 100% 3/3 [00:08<00:00,  2.82s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Drawer of validation.
#     [INFO] | Labels creation completed.
#
# Stool
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 16 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 12 images in validation.
# 100% 12/12 [00:12<00:00,  1.06s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Stool of validation.
#     [INFO] | Labels creation completed.
# Runtime: 1329.833509974 seconds.

# %% [markdown]
# ## Convert annotations
# Let's use out-of-the-box `convert_annotations.py` script to convert OID annotations to the proper YOLOv4 format. The text files are generated in folder with images.

# %%
# !python3 convert_annotations.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Sink_Stairs_Chair_Cabinetry_Desk_Studio couch_Couch_Door_Shower_Wardrobe_Nightstand_Bathtub_Houseplant_Sofa bed_Curtain_Bed_Fireplace_Bookcase_Table_Mirror_Chest of drawers_Cupboard_Coffee table_Toilet_Bench_Window_Closet_Lamp_Drawer_Stool
# 100% 11995/11995 [1:46:23<00:00,  1.88it/s]
# Currently in subdirectory: validation_old
# Converting annotations for class:  Sink_Stairs_Chair_Cabinetry_Desk_Studio couch_Couch_Door_Shower_Wardrobe_Nightstand_Bathtub_Houseplant_Sofa bed_Curtain_Bed_Fireplace_Bookcase_Table_Mirror_Chest of drawers_Cupboard_Coffee table_Toilet_Bench_Window_Closet_Lamp_Drawer_Stool
# 100% 710/710 [06:11<00:00,  1.91it/s]
# Currently in subdirectory: validation_old2
# Converting annotations for class:  Sink_Stairs_Chair_Cabinetry_Desk_Studio couch_Couch_Door_Shower_Wardrobe_Nightstand_Bathtub_Houseplant_Sofa bed_Curtain_Bed_Fireplace_Bookcase_Table_Mirror_Chest of drawers_Cupboard_Coffee table_Toilet_Bench_Window_Closet_Lamp_Drawer_Stool
# 100% 1038/1038 [08:27<00:00,  2.04it/s]
# Currently in subdirectory: validation
# Converting annotations for class:  Sink_Stairs_Chair_Cabinetry_Desk_Studio couch_Couch_Door_Shower_Wardrobe_Nightstand_Bathtub_Houseplant_Sofa bed_Curtain_Bed_Fireplace_Bookcase_Table_Mirror_Chest of drawers_Cupboard_Coffee table_Toilet_Bench_Window_Closet_Lamp_Drawer_Stool
# 100% 1042/1042 [07:55<00:00,  2.19it/s]

# %% [markdown]
# ## Move datasets
# Let's move the downloaded datasets to our data folder.

# %%
# %mkdir -p /mydrive/data/oid
# %mv OID/Dataset/train/ /mydrive/data/oid
# %mv OID/Dataset/validation/ /mydrive/data/oid
