# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/Colab Notebooks/dezeenAI
# Out:
# /content/gdrive/My Drive/Colab Notebooks/dezeenAI

# %%
import pandas as pd
import numpy as np
import timeit
from tqdm import tqdm
from os.path import basename
import os
import urllib.request
import json

# %%
articles_df = pd.read_pickle('data/articles.pkl')
articles_df
# Out:
#            id  ...                                             images
# 0     1588230  ...  [https://static.dezeen.com/uploads/2020/11/the...
# 1     1588111  ...  [https://static.dezeen.com/uploads/2020/11/iss...
# 2     1586860  ...  [https://static.dezeen.com/uploads/2020/11/noo...
# 3     1587217  ...  [https://static.dezeen.com/uploads/2020/11/pro...
# 4     1586339  ...                                                 []
# ...       ...  ...                                                ...
# 4946       70  ...  [https://static.dezeen.com/uploads/2006/12/Mar...
# 4947       67  ...  [https://static.dezeen.com/uploads/2006/12/WOK...
# 4948       54  ...  [https://static.dezeen.com/uploads/2006/12/Zah...
# 4949       48  ...  [https://static.dezeen.com/uploads/2006/12/Tho...
# 4950       15  ...  [https://static.dezeen.com/uploads/2006/11/1de...
#
# [4951 rows x 4 columns]

# %%
start = timeit.default_timer() # start the times

for _, row in tqdm(articles_df.iterrows()):
  id = row['id']
  title = row['title']  
  path = 'data/'+str(id)+'/'
  url = row['url']
  images = row['images']
  os.makedirs(path, exist_ok=True)
  info = {
      'id': id,
      'title': title,
      'url': url,
      'images': images
  }
  with open('data/'+str(id)+'/'+str(id)+'.json', 'w') as fp:
    json.dump(info, fp)

  for image in images:
    filename = basename(image)
    if not os.path.exists(path+filename):
      try: urllib.request.urlretrieve(image, path+filename)
      except: break

stop = timeit.default_timer() # stop the timer
print('\nRuntime: {} seconds.'.format(stop-start))
# Out:
# 1124it [16:44,  1.25it/s]

# %%
# f = open('data/1588230/1588230.json') 
# data = json.load(f)
