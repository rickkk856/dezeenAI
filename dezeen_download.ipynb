# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/Colab Notebooks/dezeenAIsearch
# Out:
# /content/gdrive/My Drive/Colab Notebooks/dezeenAIsearch

# %%
import requests
import urllib.request
import pandas as pd
import re
import os
from os.path import basename

# %%
articles_df = pd.read_pickle('files/articles.pkl')
articles_df
# Out:
#            id  ...                                             images
# 0     1588230  ...  [https://static.dezeen.com/uploads/2020/11/the...
# 1     1588111  ...  [https://static.dezeen.com/uploads/2020/11/iss...
# 2     1586860  ...  [https://static.dezeen.com/uploads/2020/11/noo...
# 3     1587217  ...  [https://static.dezeen.com/uploads/2020/11/pro...
# 4     1586339  ...                                                 []
# ...       ...  ...                                                ...
# 4946       70  ...  [https://static.dezeen.com/uploads/2006/12/Mar...
# 4947       67  ...  [https://static.dezeen.com/uploads/2006/12/WOK...
# 4948       54  ...  [https://static.dezeen.com/uploads/2006/12/Zah...
# 4949       48  ...  [https://static.dezeen.com/uploads/2006/12/Tho...
# 4950       15  ...  [https://static.dezeen.com/uploads/2006/11/1de...
#
# [4951 rows x 4 columns]

# %%
type(articles_df['images'][0])
# Out:
# list

# %%
url = 'https://static.dezeen.com/uploads/2020/11/issey-miyake-shop-interiors-japan-semba-shingo-noma_dezeen_hero-1-852x480.jpg'
title = 'Issey Miyake store in Osaka is splashed with water-themed details'
id = '1588111'
path = 'data/'+str(id)+'/'
filename = basename(url)
os.makedirs(path, exist_ok=True)
urllib.request.urlretrieve(url, path+filename)
# Out:
# ('data/1588111/issey-miyake-shop-interiors-japan-semba-shingo-noma_dezeen_hero-1-852x480.jpg',
#  <http.client.HTTPMessage at 0x7f1a6a7b8dd8>)
